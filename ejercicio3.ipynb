# %%
import pandas as pd
import numpy as np
import os

# %%
#carga el csv
consulta = pd.read_csv("archivos/cybersecurity_attacks.csv")

# %%
#Consultamos las primeras filas
consulta.head(10)
# Out:
#                Timestamp Source IP Address Destination IP Address  \
# 2    2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 7    2023-02-12 07:13:17      11.48.99.245         178.157.14.116
# 46   2023-05-16 13:01:56    170.211.138.30         172.97.181.148
# 97   2021-10-25 04:23:15   129.189.216.143         197.202.27.160
# 105  2022-10-30 05:51:47      62.75.113.77         216.196.28.158
# 120  2020-03-24 05:59:35    175.197.78.254           78.172.11.97
# 126  2022-05-29 09:29:50    73.162.206.250            73.201.71.6
# 144  2021-02-08 00:59:54        10.90.47.5         117.97.204.110
# 169  2020-12-28 10:10:15       14.59.56.74         75.118.190.146
# 211  2022-05-28 02:26:58    107.230.81.225          40.251.72.255
#
#      Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 2          16811             53600      UDP            306     Control
# 7          34489             20396     ICMP           1022        Data
# ...

# %%
#Eliminanos los valores nulos
consulta = consulta.dropna()

# %%
#Eliminamos valores duplicados
consulta = consulta.drop_duplicates()

# %%
#Eliminar valores atípicos en "Monthly Charge" usando rango intercuartil (IQR)
Q1 = consulta['Source Port'].quantile(0.25)
Q3 = consulta['Source Port'].quantile(0.75)
IQR = Q3 - Q1
consulta = consulta[(consulta['Source Port'] >= Q1 - 1.5 * IQR) & (consulta['Source Port'] <= Q3 + 1.5 * IQR)]
